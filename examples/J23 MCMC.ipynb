# %% [markdown]
# ## MCMC Example for Chelyabinsk Jupiter 2023

# %%
import sys
sys.path.append('../')
import numpy as np
from fragmentationmodel.planet import Planet
from fragmentationmodel.solver import MCMCSolver, denormalize
import matplotlib.pyplot as plt
import copy
import pprint
import json
import logging

logger = logging.getLogger('fragmentationmodel')
logger.setLevel(logging.ERROR)

# %% [markdown]
# ## Create the model definition function
#
# To build the model, we need a base config (i.e., defining immutable input parameters) and then a list of parameters that we allow the MCMC search to vary. For this Chelyabinsk test case, we can load the config that we used in the test case (see `Chelyabinsk.ipynb`)

# %%
with open('J23_Comet.json', 'r') as infile:
    base_config = json.load(infile)

pprint.pprint(base_config)
# Out:
# {'fragments': [{'C_fr': 1.6,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.0,
#                 'bulk_density': 800.0,
#                 'initial_mass': 718253.3333333334,
#                 'initial_strength': 620000.0,
#                 'release_pressure': 400000.0},
#                {'C_fr': 1.6,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.0,
#                 'bulk_density': 800.0,
#                 'initial_mass': 646428.0,
#                 'initial_strength': 520000.0,
#                 'release_pressure': 500000.0},
#                {'C_fr': 2.3,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.0,
#                 'bulk_density': 800.0,
#                 'initial_mass': 323214.0,
#                 'initial_strength': 600000.0,
#                 'release_pressure': 700000.0},
#                {'C_fr': 3.5,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.04,
#                 'bulk_density': 800.0,
#                 'initial_mass': 333987.8,
#                 'initial_strength': 450000.0,
#                 'release_pressure': 700000.0},
#                {'C_fr': 3.4,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.0,
#                 'bulk_density': 800.0,
#                 'initial_mass': 107737.99999999999,
#                 'initial_strength': 400000.0,
#                 'release_pressure': 500000.0},
#                {'C_fr': 2.7,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.01,
#                 'bulk_density': 800.0,
#                 'initial_mass': 165198.26666666666,
#                 'initial_strength': 510000.0,
#                 'release_pressure': 300000.0},
#                {'C_fr': 2.2,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.01,
#                 'bulk_density': 800.0,
#                 'initial_mass': 161607.0,
#                 'initial_strength': 270000.0,
#                 'release_pressure': 500000.0},
#                {'C_fr': 2.0,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.0,
#                 'bulk_density': 800.0,
#                 'initial_mass': 351944.13333333336,
#                 'initial_strength': 1200000.0,
#                 'release_pressure': 500000.0},
#                {'C_fr': 1.9,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.0,
#                 'bulk_density': 800.0,
#                 'initial_mass': 215475.99999999997,
#                 'initial_strength': 1700000.0,
#                 'release_pressure': 100000.0},
#                {'C_fr': 1.7,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.0,
#                 'bulk_density': 800.0,
#                 'initial_mass': 179563.33333333334,
#                 'initial_strength': 2200000.0,
#                 'release_pressure': 100000.0},
#                {'C_fr': 1.2,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.0,
#                 'bulk_density': 800.0,
#                 'initial_mass': 251388.6666666667,
#                 'initial_strength': 3000000.0,
#                 'release_pressure': 100000.0},
#                {'C_fr': 1.0,
#                 'ablation_coefficient': 2e-09,
#                 'alpha': 0.01,
#                 'bulk_density': 800.0,
#                 'initial_mass': 71825.33333333333,
#                 'initial_strength': 2400000.0,
#                 'release_pressure': 100000.0}],
#  'main_body': {'C_fr': 1.0,
#                'ablation_coefficient': 2e-09,
#                'alpha': 0.1,
#                'bulk_density': 800.0,
#                'initial_angle': 20.0,
#                'initial_height': 200000.0,
#                'initial_mass': 3591266.6666666665,
#                'initial_strength': 100000.0,
#                'initial_velocity': 60000.0,
#                'release_pressure': 0}}

# %% [markdown]
# ### Create the parameter space for the MCMC solver to search
#
# We create list of MCMC parameter by defining a dictionary, where each parameter name is the key and the value is a dictionary with the following keys:
#
#    * `min`: the minimum value allowed for this parameter
#    * `max`: the maximum value allowed for this parameter
#    * `location`: the location of this parameter in the configuration dictionary (with nested values separated by '.'). For example, the first fragment's initial mass fraction will have a location `fragment.1.initial_mass_fraction`, which matches the structure in the original dictionary

# %%
parameters = {
    'v': {'min': 60000., 'max': 70000., 'location': 'main_body.initial_velocity'},
    'theta': {'min': 0., 'max': 70., 'location': 'main_body.initial_angle'},
    'Ch': {'min': 1e-9, 'max': 1e-8, 'location': 'main_body.ablation_coefficient'},
    'sigma': {'min': 0.1e6, 'max': 1e6, 'location': 'main_body.initial_strength'},
    'rho_d': {'min': 500., 'max': 5000., 'location': 'main_body.bulk_density'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.1.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.1.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.1.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.2.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.2.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.2.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.3.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.3.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.3.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.4.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.4.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.4.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.5.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.5.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.5.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.6.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.6.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.6.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.7.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.7.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.7.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.8.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.8.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.8.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.9.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.9.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.9.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.10.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.10.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.10.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.11.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.11.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.11.initial_strength'},
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.12.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.12.release_pressure'},
    'sigma_frag': {'min': 5e6, 'max': 15e6, 'location': 'fragment.12.initial_strength'},
}

# %% [markdown]
# ### Initializing the solver
# With the base configuration and the search parameters defined, we can initialize the solver by defining the planet properties, and setting the reference lightcurve

# %%
planet = Planet("Jupiter")
planet.define_temperature_profile('juptp/jupiter.tp')

solver = MCMCSolver(base_config, planet)
solver.set_parameters(parameters)

# get the observed energy deposition profile
lcdata = np.loadtxt('lightcurves/lightcurve_new2.csv', delimiter=',', skiprows=2)

solver.set_lightcurve(lcdata[:, 1], lcdata[:, 3], 0.01, 'lightcurve')
solver.set_integration_parameters({'dt': 5e-3, 'max_time': 25., 'min_height': -2499000, 'max_height': 2501000})

# %% [markdown]
# ### Run the solver
#
# Run the solver by calling the `run_mcmc` method. The main arguments are the number of steps, the number of simultaneous walkers and (optionally) the number of processors to use for parallelization

# %%
sampler = solver.run_mcmc(num_steps=500, n_walkers=32, threads=10)
# Out:
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in divide
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: invalid value encountered in add
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in divide
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: invalid value encountered in add
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in log
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:153: RuntimeWarning: invalid value encountered in sqrt
#   self.state.radius = np.sqrt(S / (np.pi))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:137: RuntimeWarning: invalid value encountered in scalar power
#   sigma = s0 * (M0 / Mfr)**(alpha)
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in divide
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: invalid value encountered in add
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# emcee: Exception while calling your likelihood function:
#   params: {'v': np.float64(0.6006379616542493), 'theta': np.float64(0.0802108711038032), 'Ch': np.float64(0.9126578985337015), 'sigma': np.float64(0.9351995861169551), 'rho_d': np.float64(0.6525504507081885), 'M_frac': np.float64(0.503895382586208), 'P_release_frag': np.float64(0.2645469571899174), 'sigma_frag': np.float64(0.16962934197999213)}
#   args: ({'v': {'min': 60000.0, 'max': 70000.0, 'location': 'main_body.initial_velocity'}, 'theta': {'min': 0.0, 'max': 70.0, 'location': 'main_body.initial_angle'}, 'Ch': {'min': 1e-09, 'max': 1e-08, 'location': 'main_body.ablation_coefficient'}, 'sigma': {'min': 100000.0, 'max': 1000000.0, 'location': 'main_body.initial_strength'}, 'rho_d': {'min': 500.0, 'max': 5000.0, 'location': 'main_body.bulk_density'}, 'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.12.initial_mass_fraction'}, 'P_release_frag': {'min': 500000.0, 'max': 4000000.0, 'location': 'fragment.12.release_pressure'}, 'sigma_frag': {'min': 5000000.0, 'max': 15000000.0, 'location': 'fragment.12.initial_strength'}}, {'main_body': {'initial_mass': 3591266.6666666665, 'initial_strength': 100000.0, 'bulk_density': 800.0, 'ablation_coefficient': 2e-09, 'C_fr': 1.0, 'alpha': 0.1, 'release_pressure': 0, 'initial_height': 200000.0, 'initial_velocity': 60000.0, 'initial_angle': 20.0}, 'fragments': [{'initial_mass': 718253.3333333334, 'initial_strength': 620000.0, 'bulk_density': 800.0, 'ablation_coefficient': 2e-09, 'C_fr': 1
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
#   File "/home/kdavis/emcee/src/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py", line 232, in log_likelihood
#     df = model.integrate(**integration_parameters)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragmentation_model.py", line 176, in integrate
#     self.main_body.update(dt, min_velocity, min_height, max_height)
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py", line 111, in update
#     rho_a = self.planet.rhoz(h)
#             ^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/planet.py", line 77, in rhoz
#     return self.Pz(z) / (self.Ratmo * self.Tz(z))
#            ^^^^^^^^^^
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/planet.py", line 86, in Pz
#     return 10.**(self.logPz(z) + 2.)
#                  ^^^^^^^^^^^^^
#   File "/home/kdavis/.conda/envs/python3.11/lib/python3.11/site-packages/scipy/interpolate/_polyint.py", line 82, in __call__
#     y = self._evaluate(x)
#         ^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/.conda/envs/python3.11/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py", line 533, in _evaluate
#     below_bounds, above_bounds = self._check_bounds(x_new)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/.conda/envs/python3.11/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py", line 562, in _check_bounds
#     raise ValueError(f"A value ({below_bounds_value}) in x_new is below "
# ValueError: A value (-2498475.563983056) in x_new is below the interpolation range's minimum value (-2498000.0).
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py:133: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in divide
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: invalid value encountered in add
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in divide
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: invalid value encountered in add
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in divide
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: invalid value encountered in add
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in divide
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: invalid value encountered in add
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: divide by zero encountered in divide
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# /home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py:257: RuntimeWarning: invalid value encountered in add
#   ln_llhood = -0.5 * np.sum((model_lightcurve_interped - ref_lightcurve)**2. / (sigma_sqr) + np.log(2 * np.pi * sigma_sqr))
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/kdavis/.conda/envs/python3.11/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/.conda/envs/python3.11/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/kdavis/emcee/src/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/solver.py", line 232, in log_likelihood
#     df = model.integrate(**integration_parameters)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragmentation_model.py", line 176, in integrate
#     self.main_body.update(dt, min_velocity, min_height, max_height)
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/fragment.py", line 111, in update
#     rho_a = self.planet.rhoz(h)
#             ^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/planet.py", line 77, in rhoz
#     return self.Pz(z) / (self.Ratmo * self.Tz(z))
#            ^^^^^^^^^^
#   File "/home/kdavis/fragmentationmodel/examples/../fragmentationmodel/planet.py", line 86, in Pz
#     return 10.**(self.logPz(z) + 2.)
#                  ^^^^^^^^^^^^^
#   File "/home/kdavis/.conda/envs/python3.11/lib/python3.11/site-packages/scipy/interpolate/_polyint.py", line 82, in __call__
#     y = self._evaluate(x)
#         ^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/.conda/envs/python3.11/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py", line 533, in _evaluate
#     below_bounds, above_bounds = self._check_bounds(x_new)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kdavis/.conda/envs/python3.11/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py", line 562, in _check_bounds
#     raise ValueError(f"A value ({below_bounds_value}) in x_new is below "
# ValueError: A value (-2498475.563983056) in x_new is below the interpolation range's minimum value (-2498000.0).
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sampler = solver.run_mcmc(num_steps=500, n_walkers=32, threads=10)
#
# File ~/fragmentationmodel/examples/../fragmentationmodel/solver.py:169, in MCMCSolver.run_mcmc(self, num_steps, n_walkers, verbose, threads)
#     164 with Pool(processes=threads) as pool:
#     165     self.sampler = emcee.EnsembleSampler(n_walkers, self.ndims, log_likelihood,
#     166                                          args=(self.parameters, self.base_config, self.planet, self.integration_parameters,
#     167                                                self.ref_lightcurve, self.ref_dep_axis, self.ref_lightcurve_error, self.lightcurve_type),
#     168                                          parameter_names=self.parameter_names, pool=pool)
# --> 169     return self.sampler.run_mcmc(initial_guess, num_steps, progress=verbose)
#
# File ~/emcee/src/emcee/ensemble.py:450, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     447     initial_state = self._previous_state
#     449 results = None
# --> 450 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     451     pass
#     453 # Store so that the ``initial_state=None`` case will work
#
# File ~/emcee/src/emcee/ensemble.py:351, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     349     state.blobs = blobs0
#     350 if state.log_prob is None:
# --> 351     state.log_prob, state.blobs = self.compute_log_prob(state.coords)
#     352 if np.shape(state.log_prob) != (self.nwalkers,):
#     353     raise ValueError("incompatible input dimensions")
#
# File ~/emcee/src/emcee/ensemble.py:496, in EnsembleSampler.compute_log_prob(self, coords)
#     494     else:
#     495         map_func = map
# --> 496     results = list(map_func(self.log_prob_fn, p))
#     498 try:
#     499     # perhaps log_prob_fn returns blobs?
#     500
#    (...)
#     504     # l is a length-1 array, np.array([1.234]). In that case blob
#     505     # will become an empty list.
#     506     blob = [l[1:] for l in results if len(l) > 1]
#
# File ~/.conda/envs/python3.11/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.conda/envs/python3.11/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# ValueError: A value (-2498475.563983056) in x_new is below the interpolation range's minimum value (-2498000.0).

# %% [markdown]
# ### Analyzing the solver output
#
# We can look at how the solver compares to the known values to see how well the solver works

# %%
fig, axes = plt.subplots(solver.ndims, figsize=(10, 9), sharex=True)
samples = solver.sampler.get_chain()

labels = [r'$v$', r'$\theta$', r'$\sigma_{\rm ab}$', r'$\sigma$', r'$\rho$', r'$M_f$', r'$P_f$', r'$\sigma_{\rm frag}$']
truths=[60000, 65, 2e-8, 0.01e5, 500, 0.025, 0.975e6, 10.5e6]

for i in range(solver.ndims):
    ax = axes[i]
    param = solver.parameters[solver.parameter_names[i]]
    ax.plot(denormalize(samples[:, :, i], param['min'], param['max']), "k", alpha=0.3)
    ax.axhline(truths[i])
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
import corner
flat_samples = solver.sampler.get_chain(discard=50, thin=15, flat=True)
# de-normalize the values
for i in range(solver.ndims):
    param = solver.parameters[solver.parameter_names[i]]
    flat_samples[:, i] = denormalize(flat_samples[:, i], param['min'], param['max'])

fig = corner.corner(
    flat_samples, labels=labels, truths=truths
);
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# It's also useful to run the model again with the solver's solutions. We can do this easily by taking the input configuration and running the `Solver.get_config(new_config)` method, which will return a `FragmentationModel` object with the new loaded parameters. We can then integrate this forward to see the results

# %%
mcmc = np.percentile(solver.sampler.get_chain(discard=50, thin=15, flat=True), 50, axis=0)

frag_model_best = solver.get_new_config(mcmc)
df = frag_model_best.integrate(**solver.integration_parameters)
# Out:
# /home/kdavis/fragmodel_v5/examples/../fragmentationmodel/fragment.py:134: RuntimeWarning: invalid value encountered in scalar power
#   dSdtfr = Cfr * np.sqrt(Pram - sigma) / (M**(1. / 3.) * self.bulk_density**(1. / 6.)) * S

# %%
fig, ax = plt.subplots(1, 1, dpi=150)

# 1 kt in joules
kt = 4.184e12

# we need to interpolate the energy deposition curves from the different fragments
# onto the same height grid because they are traveling at different velocities
height = np.linspace(20, 45, 151) * 1e3
# flip the order since np.interp expects sorted x values
f1_deposited = np.interp(height, df['f1.height'][::-1], df['f1.deposited'][::-1]  * (1000 / kt))
main_deposited = np.interp(height, df['main.height'][::-1], df['main.deposited'][::-1]  * (1000 / kt))
ax.plot((main_deposited + f1_deposited), height / 1e3, 'k-', label='Modeled total deposited energy')

# plot the individual energy deposition curves
ax.plot(df['main.deposited'] * (1000 / kt), df['main.height']/1000., 'r-', label='Modeled main body', linewidth=0.8)
ax.plot(df['f1.deposited'] * (1000 / kt), df['f1.height']/1000., 'g-', label='Modeled fragment 1', linewidth=0.8)

# plot the observed data
ax.plot(energydepdata[:,1], energydepdata[:,0], 'k--', label='Observed')
ax.set_ylim((20., 45.))
ax.set_xlabel(r'Energy deposited [kt/km]')
ax.set_ylabel(r'Height [km]')
ax.legend(loc='upper right')

# %% [markdown]
# It looks like the solver has underestimated the fragment strength. So we can rerun the solver by keeping the main body parameters fixed, but prescribing a higher fragment strength. So let's get the config from the model and just tell the MCMC solver to change the fragment strength and mass fraction

# %%
base_config = copy.deepcopy(frag_model_best.get_config())  # copy the dict since we don't want to modify the dictionary in place

parameters = {
    'M_frac': {'min': 0.01, 'max': 0.05, 'location': 'fragment.1.initial_mass_fraction'},
    'P_release_frag': {'min': 0.5e6, 'max': 4e6, 'location': 'fragment.1.release_pressure'},
    'sigma_frag': {'min': 8e6, 'max': 15e6, 'location': 'fragment.1.initial_strength'},
}

planet = Planet("Earth")
planet.define_temperature_profile('earthtp/chelyabinsk_50k.tp')

solver = MCMCSolver(base_config, planet)
solver.set_parameters(parameters)

# get the observed energy deposition profile
energydepdata = np.loadtxt('energydep/ChelyabinskEnergyDep_Wheeler-et-al-2018.txt', skiprows=1)

solver.set_lightcurve(energydepdata[:, 0] * 1e3, energydepdata[:, 1], 0.01, 'energy_deposition')
solver.set_integration_parameters({'dt': 5e-3, 'max_time': 25.})

# %%
sampler = solver.run_mcmc(num_steps=100, n_walkers=32, threads=10)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [05:36<00:00,  3.37s/it]

# %% [markdown]
# Let's see the model changed here

# %%
fig, axes = plt.subplots(solver.ndims, figsize=(10, 9), sharex=True)
samples = solver.sampler.get_chain()

labels = [r'$M_f$', r'$P_f$', r'$\sigma_{\rm frag}$']
truths=[0.025, 0.975e6, 10.5e6]

for i in range(solver.ndims):
    ax = axes[i]
    param = solver.parameters[solver.parameter_names[i]]
    ax.plot(denormalize(samples[:, :, i], param['min'], param['max']), "k", alpha=0.3)
    ax.axhline(truths[i])
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
mcmc = np.percentile(solver.sampler.get_chain(discard=50, thin=15, flat=True), 50, axis=0)

frag_model_best = solver.get_new_config(mcmc)
df = frag_model_best.integrate(**solver.integration_parameters)

# %%
pprint.pprint(frag_model_best.get_config())
# Out:
# {'fragments': [{'C_fr': 1.5,
#                 'ablation_coefficient': np.float64(5.456993047349999e-09),
#                 'alpha': 0.0,
#                 'bulk_density': np.float64(3737.113100101885),
#                 'initial_mass': np.float64(128642.4981120732),
#                 'initial_strength': np.float64(11120746.262040611),
#                 'release_pressure': np.float64(3897249.5660145585)}],
#  'main_body': {'C_fr': 1.5,
#                'ablation_coefficient': np.float64(5.456993047349999e-09),
#                'alpha': 0.18,
#                'bulk_density': np.float64(3737.113100101885),
#                'initial_angle': np.float64(16.64747063623527),
#                'initial_height': 45000.0,
#                'initial_mass': 11850000.0,
#                'initial_strength': np.float64(231576.22950735135),
#                'initial_velocity': np.float64(19193.218034953352),
#                'release_pressure': 0}}

# %%
fig, ax = plt.subplots(1, 1, dpi=150)

# 1 kt in joules
kt = 4.184e12

# we need to interpolate the energy deposition curves from the different fragments
# onto the same height grid because they are traveling at different velocities
height = np.linspace(20, 45, 151) * 1e3
# flip the order since np.interp expects sorted x values
f1_deposited = np.interp(height, df['f1.height'][::-1], df['f1.deposited'][::-1]  * (1000 / kt))
main_deposited = np.interp(height, df['main.height'][::-1], df['main.deposited'][::-1]  * (1000 / kt))
ax.plot((main_deposited + f1_deposited), height / 1e3, 'k-', label='Modeled total deposited energy')

# plot the individual energy deposition curves
ax.plot(df['main.deposited'] * (1000 / kt), df['main.height']/1000., 'r-', label='Modeled main body', linewidth=0.8)
ax.plot(df['f1.deposited'] * (1000 / kt), df['f1.height']/1000., 'g-', label='Modeled fragment 1', linewidth=0.8)

# plot the observed data
ax.plot(energydepdata[:,1], energydepdata[:,0], 'k--', label='Observed')
ax.set_ylim((20., 45.))
ax.set_xlabel(r'Energy deposited [kt/km]')
ax.set_ylabel(r'Height [km]')
ax.legend(loc='upper right')

# %% [markdown]
# This improved the error in the fragment's deposition peak somewhat, but the model is struggling to distinguish between the release pressure, and it has severely underestimated the fragment mass (resulting in a lower peak energy release)! At this point, it's probably best to manually tweak the release pressure and try to find the best fit.
